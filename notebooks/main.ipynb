# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
# document.title="AiiDAlab DL_POLY"

# %%
# %%capture
from aiida import load_profile
load_profile();

# %%
from aiidalab_dlpoly.main import MainApp

app = MainApp()
